# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import keras

from keras import layers

# %%
data_train_path = "data/training_images"
data_test_path = "data/test_images"
data_validation_path = "data/validation_images"

img_width = 180
img_height = 180

# %%
data_train = keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)

data_category = data_train.class_names
# Out:
# Found 17728 files belonging to 8 classes.

# %%
data_val = keras.utils.image_dataset_from_directory(
    data_validation_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 3796 files belonging to 8 classes.

# %%
data_test = keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False
)
# Out:
# Found 3807 files belonging to 8 classes.

# %%
plt.figure(figsize=(10, 10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(image[i].numpy().astype("uint8"))
        plt.title(data_category[labels[i]])
        plt.axis("off")

# %%
from keras import Sequential # type: ignore

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([    
    layers.RandomFlip("horizontal_and_vertical"), # Data Augmentation
    layers.RandomRotation(0.2), 
    layers.RandomZoom(0.2),
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.5),
    layers.Dense(128, kernel_regularizer=keras.regularizers.l2(0.01)), # Penalizando grandes pesos por conta da diferença amostral
    layers.Dense(len(data_category))
])

# %%
model.compile(
    optimizer='adam', 
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']    
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
epochs = 25

early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(
    data_train,               # Seu dataset de treinamento
    validation_data=data_val,  # Seu dataset de validação
    epochs=epochs,             # Número de épocas (25)
    early_stopping = early_stopping
)
# Out:
# Epoch 1/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 812s 1s/step - accuracy: 0.5084 - loss: 1.4691 - val_accuracy: 0.5087 - val_loss: 1.4487
# Epoch 2/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 813s 1s/step - accuracy: 0.5082 - loss: 1.4491 - val_accuracy: 0.5087 - val_loss: 1.4489
# Epoch 3/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 815s 1s/step - accuracy: 0.5090 - loss: 1.4487 - val_accuracy: 0.5087 - val_loss: 1.4487
# Epoch 4/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 818s 1s/step - accuracy: 0.5089 - loss: 1.4476 - val_accuracy: 0.5087 - val_loss: 1.4489
# Epoch 5/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 818s 1s/step - accuracy: 0.5089 - loss: 1.4463 - val_accuracy: 0.5087 - val_loss: 1.4487
# Epoch 6/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 819s 1s/step - accuracy: 0.5097 - loss: 1.4462 - val_accuracy: 0.5087 - val_loss: 1.4488
# Epoch 7/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 817s 1s/step - accuracy: 0.5096 - loss: 1.4459 - val_accuracy: 0.5087 - val_loss: 1.4487
# Epoch 8/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 820s 1s/step - accuracy: 0.5090 - loss: 1.4464 - val_accuracy: 0.5087 - val_loss: 1.4486
# Epoch 9/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 823s 1s/step - accuracy: 0.5088 - loss: 1.4467 - val_accuracy: 0.5087 - val_loss: 1.4486
# Epoch 10/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 824s 1s/step - accuracy: 0.5089 - loss: 1.4477 - val_accuracy: 0.5087 - val_loss: 1.4485
# Epoch 11/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 822s 1s/step - accuracy: 0.5088 - loss: 1.4473 - val_accuracy: 0.5087 - val_loss: 1.4489
# Epoch 12/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 824s 1s/step - accuracy: 0.5091 - loss: 1.4453 - val_accuracy: 0.5087 - val_loss: 1.4485
# Epoch 13/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 827s 1s/step - accuracy: 0.5089 - loss: 1.4467 - val_accuracy: 0.5087 - val_loss: 1.4485
# Epoch 14/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 826s 1s/step - accuracy: 0.5092 - loss: 1.4462 - val_accuracy: 0.5087 - val_loss: 1.4486
# Epoch 15/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 825s 1s/step - accuracy: 0.5085 - loss: 1.4467 - val_accuracy: 0.5087 - val_loss: 1.4486
# Epoch 16/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 826s 1s/step - accuracy: 0.5087 - loss: 1.4474 - val_accuracy: 0.5087 - val_loss: 1.4484
# Epoch 17/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 829s 1s/step - accuracy: 0.5098 - loss: 1.4459 - val_accuracy: 0.5087 - val_loss: 1.4485
# Epoch 18/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 845s 2s/step - accuracy: 0.5095 - loss: 1.4456 - val_accuracy: 0.5087 - val_loss: 1.4485
# Epoch 19/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 846s 2s/step - accuracy: 0.5101 - loss: 1.4443 - val_accuracy: 0.5087 - val_loss: 1.4486
# Epoch 20/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 844s 2s/step - accuracy: 0.5102 - loss: 1.4440 - val_accuracy: 0.5087 - val_loss: 1.4486
# Epoch 21/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 845s 2s/step - accuracy: 0.5088 - loss: 1.4476 - val_accuracy: 0.5087 - val_loss: 1.4484
# Epoch 22/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 848s 2s/step - accuracy: 0.5102 - loss: 1.4437 - val_accuracy: 0.5087 - val_loss: 1.4486
# Epoch 23/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 844s 2s/step - accuracy: 0.5095 - loss: 1.4461 - val_accuracy: 0.5087 - val_loss: 1.4484
# Epoch 24/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 844s 2s/step - accuracy: 0.5076 - loss: 1.4488 - val_accuracy: 0.5087 - val_loss: 1.4484
# Epoch 25/25
# 554/554 ━━━━━━━━━━━━━━━━━━━━ 847s 2s/step - accuracy: 0.5084 - loss: 1.4493 - val_accuracy: 0.5087 - val_loss: 1.4485

# %%
epochs_range = range(epochs)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, history.history['loss'], label='Training Loss')
plt.plot(epochs_range, history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
model.save('melanoma_model.keras')
